# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# # Hamiltonian Catalog

# %%
from hamiltonian_catalog import *

# %% [markdown]
# ## Statistics about Hamiltonian catalog

# %%
print(get_catalog_summary())
print(f"\nFinal validation check:")
report = validate_hamiltonians()
print(f"✓ Valid: {len(report['valid'])} | ⚠ Warnings: {len(report['warnings'])}")
# Out:
# ======================================================================
# HAMILTONIAN CATALOG SUMMARY
# ======================================================================
# Total Hamiltonians: 516
#   - 1D systems: 229
#   - 2D systems: 287
#
# Categories:
#   integrable           :  15
#   chaotic              :  11
#   optical              :   9
#   nonlinear_optics     :   9
#   magnetic             :   8
#   lattice              :   8
#   exotic               :   8
#   turbulence           :   8
#   particle_physics     :   8
#   quantum              :   7
#   classical            :   7
#   string_theory        :   7
#   geometric_advanced   :   7
#   relativistic         :   6
#   biophysics           :   6
#   spin_systems         :   6
#   reaction_diffusion   :   6
#   granular             :   6
#   metamaterials        :   6
#   quantum_info         :   6
#   integrable_advanced  :   6
#   non_equilibrium      :   6
#   dark_sector          :   6
#   pure_math            :   6
#   atomic               :   5
#   astrophysics         :   5
#   plasma               :   5
#   accelerator          :   5
#   topological          :   5
#   elasticity           :   5
#   statistical          :   5
#   neuroscience         :   5
#   qft                  :   5
#   mathematical         :   5
#   active_matter        :   5
#   geophysics           :   5
#   climate              :   5
#   cavity_qed           :   5
#   defects              :   5
#   ultracold            :   5
#   quantum_gravity      :   5
#   supersymmetry        :   5
#   exotic_matter        :   5
#   quantum_info_advanced :   5
#   bsm                  :   5
#   black_holes          :   5
#   continuum_solitons   :   5
#   metaphysical         :   5
#   nonlinear            :   4
#   molecular            :   4
#   geometric            :   4
#   fluid                :   4
#   dissipative          :   4
#   econophysics         :   4
#   cosmology            :   4
#   stochastic           :   4
#   twistor              :   4
#   neutrino             :   4
#   field_theory         :   4
#   control_theory       :   4
#   acoustics            :   4
#   network_dynamics     :   4
#   spin_glass           :   4
#   mesoscopic           :   4
#   polymers             :   4
#   tft                  :   4
#   symmetry_reduced     :   4
#   quantum_topological_extended :   4
#   epidemiology         :   4
#   linguistics          :   4
#   ecology              :   4
#   inference            :   4
#   urban                :   4
#   cognitive            :   4
#   legal                :   4
#   art_music            :   4
#   education            :   4
#   religion             :   4
#   sports               :   4
#   agriculture          :   4
#   public_health        :   4
#   architecture         :   4
#   cuisine              :   4
#   fashion              :   4
#   wellness             :   4
#   digital_culture      :   4
#   folklore             :   4
#   perfumery            :   4
#   dream                :   4
#   gardening            :   4
#   typography           :   4
#   ceremony             :   4
#   mythopoetics         :   4
#   culinary             :   4
#   dance                :   4
#   poetics              :   4
#   stochastic_advanced  :   3
#   modern_extensions    :   3
#   game_dynamics        :   3
#   optimization         :   3
#   quant_finance        :   3
#   scattering           :   2
#   multi_scale_chaos    :   2
#   symbolic             :   2
#   generative           :   2
#   rotating             :   1
#   semiclassical        :   1
#   nuclear              :   1
# ======================================================================
#
# Final validation check:
# ✓ Valid: 461 | ⚠ Warnings: 55

# %% [markdown]
# ## Warnings about the weird Hamiltonians

# %%
report['warnings']
# Out:
# [{'name': 'kepler',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-k/sqrt(eps + x**2 + y**2) + (eta**2 + xi**2)/(2*m)'},
#  {'name': 'stadium_billiard_smooth',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'V0/(1 + exp(-alpha*(sqrt(x**2 + y**2) - 1))) + eta**2/2 + xi**2/2'},
#  {'name': 'dirac_coulomb',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-alpha/sqrt(eps + x**2) + sqrt(m**2 + xi**2)'},
#  {'name': 'relativistic_kepler',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-k/sqrt(eps + x**2 + y**2) + sqrt(eta**2 + m**2 + xi**2)'},
#  {'name': 'yukawa',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-g*exp(-alpha*sqrt(x**2 + y**2))/(eps + sqrt(x**2 + y**2)) + xi**2/2'},
#  {'name': 'coulomb_2d',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'eta**2/2 + xi**2/2 - 1/sqrt(eps + x**2 + y**2)'},
#  {'name': 'vortex_pair',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-log(sqrt(eps + (x - y)**2))'},
#  {'name': 'point_vortex_3',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-log(sqrt(eps + x**2 + y**2)) - log(sqrt(eps + y**2 + (x - 1)**2))'},
#  {'name': 'schwarzschild_orbit',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'alpha/(x**2 + y**2) - k/sqrt(x**2 + y**2) + (eta**2 + xi**2)/(2*m)'},
#  {'name': 'three_body_restricted',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-alpha/sqrt(eps + y**2 + (x - 1)**2) + eta**2/2 + xi**2/2 - 1/sqrt(eps + y**2 + (alpha + x)**2)'},
#  {'name': 'galactic_rotation',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-k/sqrt(eps + x**2 + y**2) + omega*(eta*x - xi*y) + (eta**2 + xi**2)/(2*m)'},
#  {'name': 'planetary_ring',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'eta**2/2 + omega**2*(x**2 + y**2)/2 + xi**2/2 - 1/sqrt(eps + x**2 + y**2)'},
#  {'name': 'fokker_planck',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': '-gamma*log(x**2 + 1) + xi**2/2'},
#  {'name': 'chemotaxis',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': '-alpha*log(x**2 + y**2 + 1) + eta**2/2 + xi**2/2'},
#  {'name': 'debye_shielding',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-g*exp(-alpha*sqrt(eps + x**2))/sqrt(eps + x**2) + xi**2/2'},
#  {'name': 'berry_phase',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'V0*x/sqrt(x**2 + y**2) + eta**2/2 + omega*(eta*x - xi*y) + xi**2/2'},
#  {'name': 'maxwell_boltzmann',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': '-k*log(1 + exp(-x)) + xi**2/(2*m)'},
#  {'name': 'fermi_dirac',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': '-k*log(1 + exp(-x/k)) + xi**2/(2*m)'},
#  {'name': 'bose_einstein',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': 'k*log(1 - exp(-x/k)) + xi**2/(2*m)'},
#  {'name': 'coleman_weinberg',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': 'alpha*x**4*log(x**2/beta) + xi**2/(2*m)'},
#  {'name': 'hasegawa_mima',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': 'alpha*log(x**2 + y**2 + 1) + eta**2/2 + xi**2/2'},
#  {'name': 'durian_foam',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'alpha*Abs(sqrt(x**2 + y**2) - 1)**2.5 + eta**2/2 + xi**2/2'},
#  {'name': 'jamming_transition',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'V0*Abs(sqrt(x**2 + y**2) - 1)**1.5*Heaviside(1 - sqrt(x**2 + y**2)) + eta**2/2 + xi**2/2'},
#  {'name': 'active_brownian',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-V0*(eta*y/sqrt(eta**2 + xi**2) + x*xi/sqrt(eta**2 + xi**2)) + eta**2/2 + xi**2/2'},
#  {'name': 'bacterial_swarm',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': '-alpha*log(x**2 + y**2 + 1) + beta*(eta*y + x*xi) + eta**2/2 + xi**2/2'},
#  {'name': 'negative_refraction',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'V0*(cos(x) + cos(y)) - sqrt(eta**2 + xi**2)'},
#  {'name': 'dirac_cone',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'V0*(cos(x) + cos(y) + cos(x - y)) + sqrt(eta**2 + xi**2)'},
#  {'name': 'core_oscillation',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'eta**2/2 - g/sqrt(eps + x**2 + y**2) + omega**2*(x**2 + y**2) + xi**2/2'},
#  {'name': 'nambu_goto',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'sqrt(eta**2 + xi**2)*sqrt(alpha*(x - y)**2 + 1)'},
#  {'name': 'dvali_gabadadze',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'alpha*sqrt(x**2 + y**2) + eta**2/2 + xi**2/2 - 1/(eps + sqrt(x**2 + y**2))'},
#  {'name': 'spin_network',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-alpha*sqrt(x*(x + 1)) - beta*sqrt(y*(y + 1))'},
#  {'name': 'hitchin_system',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': 'alpha*log(x**2 + y**2) + eta**2/2 + xi**2/2'},
#  {'name': 'kaehler_potential',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': 'alpha*log(x**2 + y**2 + 1) + eta**2/2 + xi**2/2'},
#  {'name': 'dark_photon',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-alpha*eps/(eps + sqrt(x**2 + y**2)) + (eta**2 + xi**2)/(2*m)'},
#  {'name': 'schwarzschild_particle',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'eta**2/(-4*m/sqrt(eps + x**2 + y**2) + 2) + xi**2*(-2*m/sqrt(eps + x**2 + y**2) + 1)/2'},
#  {'name': 'dirac_2d_nonuniform_B',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'sqrt(m**2 + (A*x*exp(-y**2) + eta)**2 + (-A*y*exp(-x**2) + xi)**2)'},
#  {'name': 'weyl_semimetal',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'alpha*(eta*x - xi*y) + sqrt(eta**2 + xi**2)'},
#  {'name': 'graphene_dirac',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'V0*(cos(x) + cos(y)) + sqrt(3)*eta/2 - xi/2'},
#  {'name': 'majorana_wire',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-mu + sqrt(Delta**2*sin(x)**2 + xi**2)'},
#  {'name': 'sine_gordon_2d',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'V0*(1 - cos(sqrt(x**2 + y**2))) + eta**2/2 + xi**2/2'},
#  {'name': 'mutualism_potential',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': '-alpha*log(x + 1) - beta*log(y + 1) + eta**2/2 + gamma*x*y + xi**2/2'},
#  {'name': 'variational_free_energy',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': 'alpha*x**2/2 + beta*log(cosh(x)) + xi**2/2'},
#  {'name': 'pedestrian_evacuation',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-alpha*log(eps + sqrt(x**2 + y**2)) + xi**2/(2*m)'},
#  {'name': 'belief_updating',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': 'alpha*(-beta + x)**2/2 - gamma*log(cosh(x)) + xi**2/2'},
#  {'name': 'color_harmony',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'V0*(-x/sqrt(x**2 + y**2) + 1) + eta**2/2 + xi**2/2'},
#  {'name': 'knowledge_diffusion',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-alpha*log(eps + sqrt(x**2 + y**2)) + eta**2/2 + xi**2/2'},
#  {'name': 'player_interaction',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': 'alpha/sqrt(eps + (x - y)**2) - beta*(x + y)**2 + eta**2/2 + xi**2/2'},
#  {'name': 'epidemic_preparedness',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': '-alpha*log(x**2 + y**2 + 1) + eta**2/2 + xi**2/2'},
#  {'name': 'spatial_perception',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-V0*log(eps + sqrt(x**2 + y**2)) + eta**2/2 + xi**2/2'},
#  {'name': 'meditation_potential',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': '-alpha*log(cosh(x)) + beta*x**2 + xi**2/2'},
#  {'name': 'narrative_diffusion',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-alpha*log(sqrt(eps + x**2)) + xi**2/(2*m)'},
#  {'name': 'olfactory_adaptation',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': '-alpha*log(x + 1) + beta*x**2 + xi**2/2'},
#  {'name': 'hypnagogic_potential',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': '-alpha*log(cosh(x)) + beta*sin(gamma*x) + xi**2/2'},
#  {'name': 'symbolic_energy',
#   'issues': ['Potential sqrt of negative quantity'],
#   'expression': '-alpha*log(eps + sqrt(x**2 + y**2)) + eta**2/2 + xi**2/2'},
#  {'name': 'consciousness_potential',
#   'issues': ['Logarithm without absolute value or regularization'],
#   'expression': '-alpha*log(cosh(x)) + beta*sin(gamma*x) + xi**2/2'}]

# %% [markdown]
# ## Thema classification

# %%
get_tree()
# Out:
# {'Classical & Celestial Mechanics': {'integrable': 15,
#   'chaotic': 11,
#   'nonlinear': 4,
#   'classical': 7,
#   'integrable_advanced': 6,
#   'astrophysics': 5,
#   'geophysics': 5,
#   'climate': 5},
#  'Quantum & Atomic Physics': {'quantum': 7,
#   'atomic': 5,
#   'molecular': 4,
#   'nuclear': 1,
#   'ultracold': 5,
#   'mesoscopic': 4,
#   'quantum_topological_extended': 4,
#   'semiclassical': 1},
#  'Field Theory & High-Energy Physics': {'qft': 5,
#   'particle_physics': 8,
#   'string_theory': 7,
#   'quantum_gravity': 5,
#   'supersymmetry': 5,
#   'bsm': 5,
#   'dark_sector': 6,
#   'neutrino': 4,
#   'exotic_matter': 5,
#   'field_theory': 4},
#  'Condensed Matter & Materials': {'lattice': 8,
#   'spin_systems': 6,
#   'spin_glass': 4,
#   'defects': 5,
#   'metamaterials': 6,
#   'topological': 5,
#   'quantum_info': 6,
#   'quantum_info_advanced': 5,
#   'polymers': 4},
#  'Electromagnetism & Optics': {'magnetic': 8,
#   'optical': 9,
#   'plasma': 5,
#   'cavity_qed': 5,
#   'nonlinear_optics': 9,
#   'acoustics': 4,
#   'rotating': 1},
#  'Relativity & Gravitation': {'relativistic': 6,
#   'black_holes': 5,
#   'cosmology': 4,
#   'geometric': 4,
#   'geometric_advanced': 7},
#  'Statistical & Non-Equilibrium Physics': {'statistical': 5,
#   'stochastic': 4,
#   'stochastic_advanced': 3,
#   'dissipative': 4,
#   'non_equilibrium': 6,
#   'reaction_diffusion': 6,
#   'turbulence': 8},
#  'Fluids, Soft Matter & Active Systems': {'fluid': 4,
#   'granular': 6,
#   'active_matter': 5,
#   'elasticity': 5},
#  'Solitons & Nonlinear Waves': {'continuum_solitons': 5,
#   'multi_scale_chaos': 2},
#  'Biophysics & Life Sciences': {'biophysics': 6,
#   'neuroscience': 5,
#   'epidemiology': 4,
#   'public_health': 4,
#   'ecology': 4},
#  'Engineering & Technology': {'accelerator': 5,
#   'control_theory': 4,
#   'acoustics': 4},
#  'Earth & Environmental Systems': {'geophysics': 5,
#   'climate': 5,
#   'agriculture': 4,
#   'urban': 4},
#  'Information & Computation': {'quantum_info': 6,
#   'quantum_info_advanced': 5,
#   'symbolic': 2,
#   'optimization': 3,
#   'inference': 4,
#   'network_dynamics': 4,
#   'modern_extensions': 3},
#  'Cognitive & Psychological Dynamics': {'cognitive': 4,
#   'wellness': 4,
#   'dream': 4,
#   'neuroscience': 5,
#   'education': 4},
#  'Social & Cultural Systems': {'econophysics': 4,
#   'game_dynamics': 3,
#   'linguistics': 4,
#   'religion': 4,
#   'folklore': 4,
#   'digital_culture': 4,
#   'legal': 4,
#   'sports': 4,
#   'urban': 4,
#   'quant_finance': 3},
#  'Aesthetic & Design Domains': {'art_music': 4,
#   'typography': 4,
#   'architecture': 4,
#   'perfumery': 4,
#   'fashion': 4,
#   'cuisine': 4,
#   'culinary': 4,
#   'generative': 2,
#   'dance': 4,
#   'poetics': 4},
#  'Cultural & Symbolic Practices': {'ceremony': 4,
#   'mythopoetics': 4,
#   'folklore': 4},
#  'Health & Wellness': {'wellness': 4, 'dream': 4, 'gardening': 4},
#  'Mathematical Structures': {'pure_math': 6,
#   'mathematical': 5,
#   'twistor': 4,
#   'tft': 4,
#   'symmetry_reduced': 4,
#   'exotic': 8},
#  'Metaphysical & Speculative': {'metaphysical': 5, 'exotic': 8}}

# %% [markdown]
# ## Search Hamiltonians by keywords

# %%
get_hamiltonians_by_keywords( 'wave')
# Out:
# ['acoustic_gradient',
#  'acoustic_waveguide',
#  'cyclotron_maser',
#  'derivative_nls',
#  'epidemic_wave',
#  'fiber_coupler',
#  'fisher_kpp',
#  'kadomtsev_petviashvili',
#  'negative_refraction',
#  'paraxial_wave',
#  'phononic_bandgap',
#  'photonic_waveguide_array',
#  'plasma_wave',
#  'rossby_wave',
#  'seismic_wave',
#  'soliton_potential',
#  'tsunami_wave',
#  'waveguide_bent']

# %% [markdown]
# ## List Hamiltonians

# %%
list_hamiltonians(category=None, dim=1)
# Out:
# ['ablowitz_ladik',
#  'ads_black_hole',
#  'aharonov_bohm_ring',
#  'allen_cahn',
#  'anharmonic_oscillator',
#  'archetype_potential',
#  'arrow_of_time',
#  'attention_economy',
#  'atwood_machine',
#  'aubry_andre',
#  'axion_field',
#  'belief_updating',
#  'benjamin_ono',
#  'bitter_sweet_tension',
#  'black_scholes',
#  'bogoyavlensky_lattice',
#  'bose_einstein',
#  'brachistochrone',
#  'bragg_grating',
#  'buckingham',
#  'burgers_potential',
#  'caesura_tension',
#  'cahn_hilliard',
#  'caldirola_kanai',
#  'camassa_holm',
#  'cantor_set',
#  'causal_set',
#  'chameleon_field',
#  'chromaticity',
#  'circadian_rhythm',
#  'coleman_weinberg',
#  'consciousness_potential',
#  'continuous_time_random_walk',
#  'cooking_time_opt',
#  'cornell_potential',
#  'coulomb_blockade',
#  'crooks_fluctuation',
#  'cubic_potential',
#  'damped_oscillator',
#  'debye_shielding',
#  'derivative_nls',
#  'dicke_model',
#  'diffusion_inference',
#  'dirac_coulomb',
#  'dirac_radial',
#  'dna_twist',
#  'doctrinal_evolution',
#  'double_well',
#  'dream_instability',
#  'driven_pendulum',
#  'drought_response',
#  'duffing',
#  'eckart_barrier',
#  'edwards_polymer',
#  'ekpyrotic',
#  'electroweak_phase',
#  'enjambment_flow',
#  'euler_bernoulli_beam',
#  'fast_fashion_dissipation',
#  'fermi_dirac',
#  'feshbach_resonance',
#  'fibonacci_potential',
#  'fisher_kpp',
#  'fjc_potential',
#  'flory_huggins_energy',
#  'fokker_planck',
#  'fokker_planck_nonquadratic',
#  'forgetting_potential',
#  'fractal_potential',
#  'fractional_brownian',
#  'free_particle',
#  'frenkel_kontorova',
#  'game_momentum',
#  'gaussian_barrier',
#  'glyph_rhythm',
#  'gross_neveu',
#  'gross_pitaevskii',
#  'growth_potential',
#  'growth_rhythm',
#  'harmonic_oscillator',
#  'harmonic_tension',
#  'hawk_dove_game',
#  'hawking_radiation',
#  'heat_engine',
#  'herd_immunity_threshold',
#  'hero_journey',
#  'hertz_contact',
#  'hill_potential',
#  'hodgkin_huxley_reduced',
#  'horava_lifshitz',
#  'hulthen',
#  'hypergeometric',
#  'hypnagogic_potential',
#  'ice_sheet_flow',
#  'inflaton_chaotic',
#  'inflaton_starobinsky',
#  'information_paradox',
#  'ising_mean_field',
#  'ising_transverse',
#  'jarzynski_work',
#  'jaynes_cummings',
#  'josephson_junction_bec',
#  'jurisprudential_tension',
#  'kdv_equation',
#  'kerning_potential',
#  'kibble_zurek',
#  'kitaev_chain',
#  'klein_gordon',
#  'kronig_penney',
#  'lambert_w',
#  'language_drift',
#  'learned_hamiltonian',
#  'learning_curve',
#  'legal_entropy',
#  'lennard_jones',
#  'levy_flight',
#  'levy_stable',
#  'liminal_transition',
#  'linear_potential',
#  'logical_gate_potential',
#  'lorenz96',
#  'lqr_problem',
#  'majorana_mass',
#  'majorana_wire',
#  'manning_rosen',
#  'martingale_hamiltonian',
#  'mathieu',
#  'maxwell_boltzmann',
#  'measurement_back_action',
#  'meditation_potential',
#  'meme_spread',
#  'memory_kernel_effective',
#  'metrical_potential',
#  'michaelis_menten',
#  'mooney_rivlin',
#  'morse',
#  'mpemba_effect',
#  'msw_effect',
#  'multiplicative_noise',
#  'mythic_recurrence',
#  'narrative_diffusion',
#  'neo_hookean',
#  'nesterov_ode',
#  'nls_cubic',
#  'nls_quintic',
#  'norm_diffusion',
#  'observer_effect',
#  'olfactory_adaptation',
#  'optical_lattice_bec',
#  'optomechanics',
#  'ornstein_uhlenbeck',
#  'painleve_transcendent',
#  'parton_distribution',
#  'peierls_nabarro',
#  'phantom_energy',
#  'phi4_theory',
#  'poschl_teller',
#  'potts_model',
#  'proportion_harmony',
#  'pt_symmetric',
#  'q_deformed',
#  'quantum_zeno',
#  'quark_confinement',
#  'quartic_mixed',
#  'quintessence',
#  'rabi_oscillation',
#  'random_field_ising',
#  'rayleigh_oscillator',
#  'reduced_rotor',
#  'regge_trajectory',
#  'religious_entropy',
#  'rem_cycle',
#  'replicator_hamiltonian',
#  'rf_cavity',
#  'rhythmic_tension',
#  'riemann_hypothesis',
#  'risk_measure_flow',
#  'ritual_periodicity',
#  'ritual_timing',
#  'roller_coaster',
#  'rosen_morse',
#  'rumor_dynamics',
#  'run_and_tumble',
#  'schwarzschild_radial',
#  'seasonal_cycle',
#  'semi_classical',
#  'sextic_oscillator',
#  'shallow_water',
#  'sine_gordon',
#  'soil_nutrient_diffusion',
#  'soliton_potential',
#  'stick_slip',
#  'strangelets',
#  'stress_recovery',
#  'style_cycles',
#  'su_schrieffer_heeger',
#  'sugra_scalar',
#  'supersymmetric_qm',
#  'susy_harmonic',
#  'symplectic_sgd',
#  'synchrotron_radiation',
#  'taste_sequencing',
#  'thirring_model',
#  'threshold_crossing',
#  'tidal_force',
#  'traffic_flow',
#  'transverse_ising_chain',
#  'trend_diffusion',
#  'tsunami_wave',
#  'twin_boundary',
#  'umami_potential',
#  'vacancy_diffusion',
#  'vaccination_campaign',
#  'vaccination_game',
#  'variational_free_energy',
#  'vlasov_poisson',
#  'void_dynamics',
#  'volatility_gradient',
#  'wannier_stark',
#  'wdvv_potential',
#  'weierstrass',
#  'wheeler_dewitt',
#  'wimp_scattering',
#  'witten_index',
#  'woods_saxon',
#  'working_memory',
#  'worm_like_chain',
#  'zeta_potential',
#  'zipf_law_potential']

# %%
get_hamiltonian(name='tsunami_wave')
# Out:
# (g*sqrt(x) + xi**2/(2*m),
#  (x, xi),
#  {'expr': g*sqrt(x) + xi**2/(2*m),
#   'dim': 1,
#   'category': 'geophysics',
#   'description': 'Tsunami propagation — shallow water approximation.'})

# %% [markdown]
# ## Search similiar Hamiltonians

# %%
name = 'seismic_wave'
find_similar_hamiltonians(name=name, top_n=5)
# Out:
# [('mantle_convection', 108),
#  ('core_oscillation', 107),
#  ('dynamo_effect', 97),
#  ('tsunami_wave', 79),
#  ('landau_levels', 70)]

# %% [markdown]
# ## Hamiltonian dimension analysis

# %%
get_dimensional_analysis(name=name)
# Out:
# {'name': 'seismic_wave',
#  'dimension': 2,
#  'num_terms': 1,
#  'polynomial_degree': 2,
#  'has_trigonometric': False,
#  'has_exponential': True,
#  'has_logarithm': False,
#  'has_sqrt': False,
#  'has_abs': False,
#  'has_rational': True,
#  'complexity_score': 73}

# %% [markdown]
# ## Hamiltonian information

# %%
get_hamiltonian(name=name)
# Out:
# ((eta**2 + xi**2)/(2*alpha*exp(-beta*y) + 2),
#  (x, y, xi, eta),
#  {'expr': (eta**2 + xi**2)/(2*alpha*exp(-beta*y) + 2),
#   'dim': 2,
#   'category': 'geophysics',
#   'description': 'Seismic wave in stratified medium.'})
